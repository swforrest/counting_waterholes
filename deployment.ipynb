# %% [markdown]
# ### Running a deployment with quick modifications of the classify functions of Charlie.
#
# In the process, the main issue is that the classes and clusters combinations are made sole on the definintions inputs or hard inputs of functions. So all the inputs need to be adapted and the structure of those will change

# %%
import comet_ml
import datetime
import os
import argparse
import time
import typer
import pandas as pd
import numpy as np
import math


import os.path as path
import scipy.cluster
import scipy.spatial
import json
from datetime import datetime
from counting_boats.boat_utils import image_cutting_support as ics
from counting_boats.boat_utils.config import cfg
from tqdm import tqdm
import torch
import stat
import shutil
import pathlib


from counting_boats.boat_utils.config import cfg
from counting_boats.boat_utils import planet_utils as pu
from counting_boats.boat_utils import classifier as cl
from counting_boats.boat_utils import auto_helpers as ah

# %%
from counting_boats.boat_utils import classifier
